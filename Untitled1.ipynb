# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("IPL_Matches_2008_2022.csv")

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
change={"Delhi Daredevils":"Delhi Capitals","Kings XI Punjab":"Punjab Kings","Rising Pune Supergiants":"Rising Pune Supergiant"}
df=df.replace(change.keys(),change.values())

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.groupby("Season")["WinningTeam"].apply(lambda x:x.value_counts().head(1))
# Out:
# Season
# 2007/08  Rajasthan Royals         13
# 2009     Delhi Capitals           10
# 2009/10  Mumbai Indians           11
# 2011     Chennai Super Kings      11
# 2012     Kolkata Knight Riders    12
# 2013     Mumbai Indians           13
# 2014     Punjab Kings             12
# 2015     Mumbai Indians           10
# 2016     Sunrisers Hyderabad      11
# 2017     Mumbai Indians           12
# 2018     Chennai Super Kings      11
# 2019     Mumbai Indians           11
# 2020/21  Mumbai Indians           11
# 2021     Chennai Super Kings      11
# 2022     Gujarat Titans           12
# Name: WinningTeam, dtype: int64

# %%
df.groupby("WinningTeam")["Player_of_Match"].nunique().sort_values(ascending=False)
# Out:
# WinningTeam
# Delhi Capitals                 50
# Punjab Kings                   49
# Kolkata Knight Riders          44
# Mumbai Indians                 43
# Rajasthan Royals               41
# Chennai Super Kings            39
# Royal Challengers Bangalore    36
# Sunrisers Hyderabad            36
# Deccan Chargers                19
# Pune Warriors                  11
# Gujarat Titans                  9
# Rising Pune Supergiant          9
# Gujarat Lions                   7
# Lucknow Super Giants            6
# Kochi Tuskers Kerala            4
# Name: Player_of_Match, dtype: int64

# %%
df.groupby(['TossDecision',"WinningTeam"],as_index=False).size().sort_values("size",ascending=False)
# Out:
#    TossDecision                  WinningTeam  size
# 22        field               Mumbai Indians    79
# 24        field                 Punjab Kings    75
# 27        field  Royal Challengers Bangalore    74
# 20        field        Kolkata Knight Riders    72
# 16        field               Delhi Capitals    66
# 14        field          Chennai Super Kings    62
# 0           bat          Chennai Super Kings    59
# 25        field             Rajasthan Royals    56
# 7           bat               Mumbai Indians    52
# 28        field          Sunrisers Hyderabad    50
# 5           bat        Kolkata Knight Riders    42
# 10          bat             Rajasthan Royals    40
# 2           bat               Delhi Capitals    37
# 12          bat  Royal Challengers Bangalore    35
# 9           bat                 Punjab Kings    26
# 13          bat          Sunrisers Hyderabad    25
# 15        field              Deccan Chargers    15
# ...

# %%
df.Venue.value_counts()
# Out:
# Venue
# Eden Gardens                                            77
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Feroz Shah Kotla                                        60
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Sawai Mansingh Stadium                                  47
# Dubai International Cricket Stadium                     46
# Punjab Cricket Association Stadium, Mohali              35
# Wankhede Stadium, Mumbai                                31
# Sheikh Zayed Stadium                                    29
# Sharjah Cricket Stadium                                 28
# Maharashtra Cricket Association Stadium                 22
# Dr DY Patil Sports Academy, Mumbai                      20
# Dr DY Patil Sports Academy                              17
# Brabourne Stadium, Mumbai                               17
# ...

# %%
df1=df.Venue.value_counts().head(5)
df1=df1.reset_index()

# %%
df1
# Out:
#                                        Venue  count
# 0                               Eden Gardens     77
# 1                           Wankhede Stadium     73
# 2                      M Chinnaswamy Stadium     65
# 3                           Feroz Shah Kotla     60
# 4  Rajiv Gandhi International Stadium, Uppal     49

# %%
df.shape
# Out:
# (950, 20)

# %%
df2=df1.merge(df,on="Venue",how="inner")
df2.shape
# Out:
# (324, 21)

# %%
df2.groupby("Venue")["WinningTeam"].apply(lambda x:x.value_counts().head(1)).sort_values(ascending=False)
# Out:
# Venue
# Eden Gardens                               Kolkata Knight Riders          45
# Wankhede Stadium                           Mumbai Indians                 42
# M Chinnaswamy Stadium                      Royal Challengers Bangalore    29
# Feroz Shah Kotla                           Delhi Capitals                 23
# Rajiv Gandhi International Stadium, Uppal  Sunrisers Hyderabad            20
# Name: WinningTeam, dtype: int64

# %%
ma
