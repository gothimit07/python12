# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("production_analysis_dataset.csv")

# %%
df
# Out:
#     production_id product_category  factory    shift supervisor  \
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 2             103      Electronics  Plant_A    Night         S4
# 3             104      Electronics  Plant_B  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 7             108      Electronics  Plant_B  Evening         S3
# 8             109      Electronics  Plant_A  Morning         S3
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 11            112        Furniture  Plant_A  Morning         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 13            114        Furniture  Plant_C  Evening         S1
# ...

# %%
pd.get_dummies(df)
# Out:
#     production_id  units_produced  defective_units  production_time_hr  \
# 0             101             627               12                6.58
# 1             102             602               32                6.60
# 2             103             666               39                7.76
# 3             104             474               22                6.97
# 4             105             476               21                8.92
# 5             106             621               28                8.23
# 6             107             351               29                7.33
# 7             108             659                9                8.33
# 8             109             627               40                7.16
# 9             110             505               22                6.70
# 10            111             502               34                6.93
# 11            112             598               30                7.59
# ...

# %%
pd.get_dummies(df,"shift").head()
# Out:
#    production_id  units_produced  defective_units  production_time_hr  \
# 0            101             627               12                6.58
# 1            102             602               32                6.60
# 2            103             666               39                7.76
# 3            104             474               22                6.97
# 4            105             476               21                8.92
#
#    machine_downtime_hr  energy_consumption_kwh  profit  shift_Automotive  \
# 0                 0.56                    1028   12286              True
# 1                 0.32                    1038   18279              True
# 2                 0.78                    1084   23261             False
# 3                 1.44                    1144   11674             False
# 4                 1.15                    1349   12045             False
#
#    shift_Electronics  shift_Furniture  shift_Plant_A  shift_Plant_B  \
# ...

# %%
pd.get_dummies(df).shape
# Out:
# (50, 20)

# %%
pd.get_dummies(df,drop_first=True).shape
# Out:
# (50, 16)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df["defective_units"]
y=df.drop("defective_units",axis=1)

# %%
x
# Out:
# 0     12
# 1     32
# 2     39
# 3     22
# 4     21
# 5     28
# 6     29
# 7      9
# 8     40
# 9     22
# 10    34
# 11    30
# 12    15
# 13     5
# 14    32
# 15    11
# 16    15
# 17    28
# 18    36
# 19    15
# 20    24
# 21     9
# 22     9
# 23    39
# 24    11
# 25    30
# 26    32
# 27    20
# 28    29
# 29    17
# 30     8
# 31     9
# 32    10
# 33    21
# 34    11
# 35    15
# 36    11
# 37    23
# 38     8
# 39    33
# 40    40
# 41    11
# 42    31
# 43    15
# 44    24
# 45     9
# 46    12
# 47    25
# 48    32
# 49    32
# Name: defective_units, dtype: int64

# %%
y
# Out:
#     production_id product_category  factory    shift supervisor  \
# 0             101       Automotive  Plant_A    Night         S1
# 1             102       Automotive  Plant_A    Night         S2
# 2             103      Electronics  Plant_A    Night         S4
# 3             104      Electronics  Plant_B  Morning         S3
# 4             105        Furniture  Plant_A    Night         S3
# 5             106      Electronics  Plant_B  Morning         S2
# 6             107        Furniture  Plant_B  Morning         S3
# 7             108      Electronics  Plant_B  Evening         S3
# 8             109      Electronics  Plant_A  Morning         S3
# 9             110       Automotive  Plant_B  Morning         S4
# 10            111       Automotive  Plant_B    Night         S4
# 11            112        Furniture  Plant_A  Morning         S1
# 12            113        Furniture  Plant_C  Evening         S3
# 13            114        Furniture  Plant_C  Evening         S1
# ...

# %%
x.shape,y.shape
# Out:
# ((50,), (50, 10))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (40,)
# (40, 10)
# (10,)
# (10, 10)

# %%
 df=pd.DataFrame([10,50,40,30,90,60,80],columns=['mark'])

# %%
df
# Out:
#    mark
# 0    10
# 1    50
# 2    40
# 3    30
# 4    90
# 5    60
# 6    80

# %%
df['grade']=np.where(df.mark>64,'high',np.where(df.mark>40,'medium','low'))

# %%
df
# Out:
#    mark   grade
# 0    10     low
# 1    50  medium
# 2    40     low
# 3    30     low
# 4    90    high
# 5    60  medium
# 6    80    high

# %%
df=pd.read_csv("IPL_Matches_2008_2022.csv")

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.Team1.unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
df.groupby('Season')['WinningTeam'].apply(lambda x:x.value_counts().head(1))
# Out:
# Season
# 2007/08  Rajasthan Royals         13
# 2009     Delhi Daredevils         10
# 2009/10  Mumbai Indians           11
# 2011     Chennai Super Kings      11
# 2012     Kolkata Knight Riders    12
# 2013     Mumbai Indians           13
# 2014     Kings XI Punjab          12
# 2015     Mumbai Indians           10
# 2016     Sunrisers Hyderabad      11
# 2017     Mumbai Indians           12
# 2018     Chennai Super Kings      11
# 2019     Mumbai Indians           11
# 2020/21  Mumbai Indians           11
# 2021     Chennai Super Kings      11
# 2022     Gujarat Titans           12
# Name: WinningTeam, dtype: int64
